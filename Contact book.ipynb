# %%
#Cantact Book Program

class Contact:
    def __init__(self, name, phone_number):
        self.name = name
        self.phone_number = phone_number
        


class ContactManager:
    def __init__(self):
        self.contacts = []

    def add_contact(self, contact):
        self.contacts.append(contact)

    def view_contacts(self):
        print("\nContact List:")
        for index, contact in enumerate(self.contacts, start=1):
            print(f"{index}. Name: {contact.name}, Phone: {contact.phone_number}")

    def search_contact(self, keyword):
        print("\nSearch Results:")
        found = False
        for contact in self.contacts:
            if keyword.lower() in contact.name.lower() or keyword in contact.phone_number:
                print(f"Name: {contact.name}, Phone: {contact.phone_number}")
                found = True
        if not found:
            print("No matching contacts found.")

    def update_contact(self, name):
        for contact in self.contacts:
            if name.lower() == contact.name.lower():
                new_name = input("Enter new name (leave empty to keep the same): ").strip()
                new_phone = input("Enter new phone number (leave empty to keep the same): ").strip()
     

                if new_name:
                    contact.name = new_name
                if new_phone:
                    contact.phone_number = new_phone
                
                print("Contact updated successfully.")
                return
        print("Contact not found.")

    def delete_contact(self, name):
        for contact in self.contacts:
            if name.lower() == contact.name.lower():
                self.contacts.remove(contact)
                print("Contact deleted successfully.")
                return
        print("Contact not found.")

def main():
    contact_manager = ContactManager()

    while True:
        print("\n1. Add Contact")
        print("2. View Contact List")
        print("3. Search Contact")
        print("4. Update Contact")
        print("5. Delete Contact")
        print("6. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            name = input("Enter name: ")
            phone_number = input("Enter phone number: ")
            contact = Contact(name, phone_number)
            contact_manager.add_contact(contact)
            print("Contact added successfully!")

        elif choice == "2":
            contact_manager.view_contacts()

        elif choice == "3":
            keyword = input("Enter name or phone number to search: ")
            contact_manager.search_contact(keyword)

        elif choice == "4":
            name = input("Enter name of contact to update: ")
            contact_manager.update_contact(name)

        elif choice == "5":
            name = input("Enter name of contact to delete: ")
            contact_manager.delete_contact(name)

        elif choice == "6":
            print("Exiting...")
            break

        else:
            print("Invalid choice!")

if __name__ == "__main__":
    main()
# Out:
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 1
# Enter name: rakshu
# Enter phone number: 5953646513
# Contact added successfully!
#
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 4
# Enter name of contact to update: ram
# Contact not found.
#
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 4
# Enter name of contact to update: rakshu
# Enter new name (leave empty to keep the same): ram
# Enter new phone number (leave empty to keep the same): 321846516841
# Contact updated successfully.
#
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Enter your choice: 2
#
# Contact List:
# 1. Name: ram, Phone: 321846516841
#
# 1. Add Contact
# 2. View Contact List
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
